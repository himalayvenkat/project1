# %%
print('pandas')
# Out:
# pandas

# %%
# data frame is a 2d table and we will take this data from the csv file
# and then we will convert it into the DF (DataFrame)
# and there in DF we will clean , analyze the data etc...

# Excel is independent platform so we can not use it , but the pandas can be used to so many PFs
# Steps
# 1. Data will be uncleaned
# 2. Data needs to be cleaned
# 3. Eleminate the wrong Data
# 4.Empty values

# %%
import pandas as pd
# Importing pandas

# %%
# Syntax for DataFrame
# df=pd.DataFrame[data,index,coloums]
# print(df) ---> it will gives the DF

# %%
df=pd.DataFrame("Himalay",'c001','Name')
print(df)
# Data, index , coloum all are optional
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-57d09c0bed1d> in <cell line: 1>()
# ----> 1 df=pd.DataFrame("Himalay",'c001','Name')
#       2 print(df)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     886                 raise ValueError("DataFrame constructor not properly called!")
#     887
# --> 888             index = ensure_index(index)
#     889             columns = ensure_index(columns)
#     890
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    7647             return Index(index_like, copy=copy, tupleize_cols=False)
#    7648     else:
# -> 7649         return Index(index_like, copy=copy)
#    7650
#    7651
#
# ...

# %%
a = [10,20,30,40,50]
df = pd.DataFrame(a)
print(df)
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50

# %%
print(df[0][0]) # df[coloum][row]
# Out:
# 10

# %%
print(df[0][4])
# Out:
# 50

# %%
data = {"cal":[200,300,400],"duration":[20,30,40]}
df = pd.DataFrame(data)
print(df)
# Out:
#    cal  duration
# 0  200        20
# 1  300        30
# 2  400        40

# %%
print(df['cal'][0])
# Out:
# 200

# %%
a = [[10,20,30,40,50],[20,22,2020]]
df = pd.DataFrame(a)
print(df)
# NaN = missing values
# Out:
#     0   1     2     3     4
# 0  10  20    30  40.0  50.0
# 1  20  22  2020   NaN   NaN

# %%
a = [[[10,20,30,40,50],[20,22,2020],[[10,20,30,40,50],[20,22,2020]]]]
df = pd.DataFrame(a)
print(df)
# Out:
#                       0               1  \
# 0  [10, 20, 30, 40, 50]  [20, 22, 2020]
#
#                                         2
# 0  [[10, 20, 30, 40, 50], [20, 22, 2020]]

# %%
a = [[[10,20,30,40,50],[20,22,2020]],[["A",'b','c'],['d','e','f']]]
df = pd.DataFrame(a)
print(df)
# Out:
#                       0               1
# 0  [10, 20, 30, 40, 50]  [20, 22, 2020]
# 1             [A, b, c]       [d, e, f]

# %%
df = pd.DataFrame(a,index=["aku","paku"],columns=["pakodi","kodi"])
print(df)
# Out:
#                     pakodi            kodi
# aku   [10, 20, 30, 40, 50]  [20, 22, 2020]
# paku             [A, b, c]       [d, e, f]

# %%
import numpy as np
np.random.seed(101)
from numpy.random import randn
df = pd.DataFrame(randn(5,4),index="A B C D E".split(),columns=['w','x','y','z'])
print(df)
# Out:
#           w         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['x']
# Out:
# A    0.628133
# B   -0.319318
# C    0.740122
# D   -0.758872
# E    1.978757
# Name: x, dtype: float64

# %%
df[['x','z']]
# Out:
#           x         z
# A  0.628133  0.503826
# B -0.319318  0.605965
# C  0.740122 -0.589001
# D -0.758872  0.955057
# E  1.978757  0.683509

# %%
df[['x','z','y']]
# Out:
#           x         z         y
# A  0.628133  0.503826  0.907969
# B -0.319318  0.605965 -0.848077
# C  0.740122 -0.589001  0.528813
# D -0.758872  0.955057 -0.933237
# E  1.978757  0.683509  2.605967

# %%
df['n']=df['x']+df['z']

# %%
df
# Out:
#           w         x         y         z         n
# A  2.706850  0.628133  0.907969  0.503826  1.131958
# B  0.651118 -0.319318 -0.848077  0.605965  0.286647
# C -2.018168  0.740122  0.528813 -0.589001  0.151122
# D  0.188695 -0.758872 -0.933237  0.955057  0.196184
# E  0.190794  1.978757  2.605967  0.683509  2.662266

# %%
# delete a column
print(df.drop('n',axis=1)) # as its a view , so it will be deleted in view but not in orginala
# axis =0 (Row basis)
# axis = 1 (column basis)
df
# Out:
#           w         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509
#           w         x         y         z         n
# A  2.706850  0.628133  0.907969  0.503826  1.131958
# B  0.651118 -0.319318 -0.848077  0.605965  0.286647
# C -2.018168  0.740122  0.528813 -0.589001  0.151122
# D  0.188695 -0.758872 -0.933237  0.955057  0.196184
# E  0.190794  1.978757  2.605967  0.683509  2.662266

# %%
# to drop permentely

# %%
df.drop('n',axis=1,inplace=True)

# %%
df
# Out:
#           w         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
# rows

df.loc['A']
# Out:
# w    2.706850
# x    0.628133
# y    0.907969
# z    0.503826
# Name: A, dtype: float64

# %%
df.iloc[1] # 1 means index
# Out:
# w    0.651118
# x   -0.319318
# y   -0.848077
# z    0.605965
# Name: B, dtype: float64

# %%
df.iloc[4]
# Out:
# w    0.190794
# x    1.978757
# y    2.605967
# z    0.683509
# Name: E, dtype: float64

# %%
# Subset to locate a perticular value

df.loc['A','z']
# Out:
# 0.5038257538223936

# %%
df.loc[['B','C'],['x','y']]
# Out:
#           x         y
# B -0.319318 -0.848077
# C  0.740122  0.528813

# %%
df
# Out:
#           w         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
# conditions

# %%
df>0
# Out:
#        w      x      y      z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True

# %%
df[df>0]
# Out:
#           w         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
a=df[df['w']>0]

# %%
print(a)
# Out:
#           w         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
a
# Out:
#           w         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df['w']>0]['y']
# Out:
# A    0.907969
# B   -0.848077
# D   -0.933237
# E    2.605967
# Name: y, dtype: float64

# %%
dd = df[(df['w']>0) & (df['y']>1)]

# %%
dd
# Out:
#           w         x         y         z
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df['w']>0]
# Out:
#           w         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           w         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index(inplace=True)
df
# Out:
#    level_0 index         w         x         y         z
# 0        0     A  2.706850  0.628133  0.907969  0.503826
# 1        1     B  0.651118 -0.319318 -0.848077  0.605965
# 2        2     C -2.018168  0.740122  0.528813 -0.589001
# 3        3     D  0.188695 -0.758872 -0.933237  0.955057
# 4        4     E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#    level_0 index         w         x         y         z
# 0        0     A  2.706850  0.628133  0.907969  0.503826
# 1        1     B  0.651118 -0.319318 -0.848077  0.605965
# 2        2     C -2.018168  0.740122  0.528813 -0.589001
# 3        3     D  0.188695 -0.758872 -0.933237  0.955057
# 4        4     E  0.190794  1.978757  2.605967  0.683509

# %%
# loading of data from csv

# %%
df = pd.read_csv('data.csv')
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
pd.options.display.max_rows = 1000

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
df.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.tail(20)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 149        60    110       150     409.4
# 150        60    106       134     343.0
# 151        60    109       129     353.2
# 152        60    109       138     374.0
# 153        30    150       167     275.8
# 154        60    105       128     328.0
# 155        60    111       151     368.5
# 156        60     97       131     270.4
# 157        60    100       120     270.4
# 158        60    114       150     382.8
# 159        30     80       120     240.9
# 160        30     85       120     250.4
# 161        45     90       130     260.4
# 162        45     95       130     270.0
# 163        45    100       140     280.9
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
# Training is done for day5 trainer notes

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('dirtydata.csv')
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
print(df.duplicated()) # it will show the duplicates values
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
df.drop_duplicates(inplace=True) # duplicated deleted

# %%
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...
